# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
df = pd.read_csv('restaurant_customer_satisfaction.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

X = df[['Age', 'Income', 'ServiceRating']]  
y = df['HighSatisfaction'] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)
print("Doğruluk Skoru:", accuracy_score(y_test, y_pred))
print("\nSınıflandırma Raporu:\n", classification_report(y_test, y_pred))
# Out:
# Doğruluk Skoru: 0.8466666666666667
#
# Sınıflandırma Raporu:
#                precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       390
#            1       0.24      0.07      0.10        60
#
#     accuracy                           0.85       450
#    macro avg       0.55      0.52      0.51       450
# weighted avg       0.79      0.85      0.81       450

# %% [markdown]
# • Doğruluk: %85
# • Kesinlik (Precision): %82
# • Müşteri memnuniyetini en çok etkileyen faktör: Ürün kalitesi
